# %% [markdown]
# #### Q1. What is an Exception in python? Write the difference between Exceptions and Syntax errors.

# %% [markdown]
# Ans:- Exception is a unwanted situation come at runtime of program and if we not handle that exception properly it will terminate the program which occurs during the execution of a program that disrupts the normal flow of the program's instructions. In general, when a Python script encounters a situation that it cannot cope with, it raises an exception. An exception is a Python object that represents an error.
#
# When a Python script raises an exception, it must either handle the exception immediately otherwise it terminates and quits.
#
# difference between exception and syntax errors
# . both are two distinct types of errors.
#
# 1) Syntax Error:- it is occurs when there is a mistake in the code's structure, making a invalid python syntax, this usually happens during the parsing phase, missing colons, incorrect indentation
#
# 2) Exception:- it is occurs during the exceution of a python program  when something unexpected happen. it can be due to various reasons, due to zero divison error, file not found and it is handled by try except block

# %% [markdown]
# #### Q2. What happens when an exception is not handled? Explain with an example.
#
# Ans:- when exception is not handled it leads to the termination of the program, and an erro trackback is display, When an exception occurred, if you don’t handle it, the program terminates abruptly and the code past the line that caused the exception will not get executed.  it leads to an "unhandled exception" situation, which can have various consequences depending on the environment in which the code is running.
#
# Termination of Program:when an exception is not caught and handled, the program will terminate immediately.
#
# Error Reporting: The programming environment or runtime might generate an error report or crash log that developers
#
# Resource Leaks: In some cases, an unhandled exception can lead to resource leaks.
#
# Data Corruption: In certain situations, an unhandled exception might leave data in an inconsistent state.
#
# Unpredictable Behavior: An unhandled exception can result in unpredictable behavior in the program. This might manifest as incorrect outputs, crashes

# %%
def division(a,b):
    return a/b

result=division(10,0)
print("division number is:-",result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 def division(a,b):
#       2     return a/b
# ----> 4 result=division(10,0)
#       5 print("division number is:-",result)
#
# Cell In[1], line 2, in division(a, b)
#       1 def division(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
def division1(a,b):
    try:
        return a/b
    except ZeroDivisionError as e:
        print("Zero division error", e)
result=division1(10,0)
print("division answer is:-",result)
# Out:
# Zero division error division by zero
# division answer is:- None

# %% [markdown]
# #### Q3. Which Python statements are used to catch and handle exceptions? Explain with an example.

# %% [markdown]
# try-except statement is used to catch and handle the exceptions. it allow you to handle errors and preventing the program from terminating, In Python, exceptions are caught and handled using the try, except, else, and finally statements. The basic syntax for handling exceptions is as follows:

# %%
def divide_numbers(a, b):
    try:
        result = a / b
    except ZeroDivisionError as e:
        print("Error: Cannot divide by zero.")
    else:
        print(f"The result of {a} divided by {b} is {result}.")
    finally:
        print("The 'divide_numbers' function has completed its execution.")


divide_numbers(10, 2)
divide_numbers(5, 0)
# Out:
# The result of 10 divided by 2 is 5.0.
# The 'divide_numbers' function has completed its execution.
# Error: Cannot divide by zero.
# The 'divide_numbers' function has completed its execution.

# %%
Q4. Explain with an example: 

a. try and else

b. finally

c. raise

# %% [markdown]
# #### try and else
# Ans:- try and else statmement is used when try block run succesfully then else block excecute otherwise except block run, try block contain code that might raise an exception and else block is optional and get executed only if no exception occurs in the try block,
# The try and else blocks work together. The code inside the try block is attempted, and if an exception occurs, it is caught in the corresponding except block. If no exception occurs during the execution of the try block, the code inside the else block will be executed.

# %%
try:
    x=10/2
    print(x)
except Exception as e:
    print(e)
else:
    print("try block run succesfully")
# Out:
# 5.0
# try block run succesfully

# %% [markdown]
# #### finally
# Ans:-finally block is used in conjuction with the try block and is executed regardless of whether an exception occurs or not. the main aim of finally block is to cleanup actions that should always be performed, like closing files or releasing resources,
# The finally block is used to specify code that should always be executed, regardless of whether an exception occurred or not. It is typically used to perform cleanup operations or release resources.

# %%
try:
    file=open("exam.txt","r")
    content=file.read();
    print(content)
except FileNotFoundError as e:
    print("file is not present")
finally:
    print("clean done")
    file.close()
# Out:
# file is not present
# clean done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 finally:
#       8     print("clean done")
# ----> 9     file.close()
#
# NameError: name 'file' is not defined

# %% [markdown]
# #### raise
# ans:- raise keyword is used to explicitly raise an exception in python. you can use it as a signal that something unexcepted happen during the exceution of your code,
# The raise statement is used to explicitly raise an exception in Python. It allows you to create custom exceptions or raise built-in exceptions under specific conditions.

# %%
def age_checker(age):
    if age<0:
        raise ValueError("Age cannot be negative.")
    elif age<18:
        print("you are a minor.")
    else:
        print("you are an adult")

try:
    age=int(input("Enter your age"))
    age_checker(age)
except ValueError as e:
    print(e)
# Out:
# Enter your age -12
# Age cannot be negative.

# %% [markdown]
# class ValueError(Exception):
#
#      def __init__(self,msg):
#
#          self.msg=msg
# you can add this to in above code but the code works properly regardless it is present or not

# %% [markdown]
# #### Q5. What are Custom Exceptions in python? Why do we need Custom Exceptions? Explain with an example.
#
# Ans:- Custom exception also know as user-define exception that are created by the programmer to represent the specific error conditions in thier code, you can create custom exception with the help of inherit the "Exception" class
#
# Custom exception are used to customize the exception according to the user needs, so can create your own exception class and throw, we need custom exception when we want to create different exception from inbuilt exception

# %%
class valid_sal(Exception):
    def __init__(self,msg):
        self.msg=msg
        
def tax(salary):
    if salary<0:
        raise valid_sal("Salary should not be less then zero")
    elif salary>0:
        print("you should give tax")

try:
    sal=int(input("Enter you salary"))
    tax(sal)
except valid_sal as v:
    print(v)
# Out:
# Enter you salary 34
# you should give tax

# %% [markdown]
# #### Q6. Create a custom exception class. Use this class to handle an exception.

# %%
def tax(salary):
    if salary<0:
        raise valid_sal("Salary should not be less then zero")
    elif salary>0:
        print("you should give tax")

try:
    sal=int(input("Enter you salary"))
    tax(sal)
except valid_sal as v:
    print(v)
# Out:
# Enter you salary -12
# Salary should not be less then zero
